# %%
import pandas as pd

# %%
pd.read_csv('facebook_reactions.csv')
# Out:
#     poster  friend reaction  date_day  post_id
# 0        2       1     like         1        0
# 1        2       6     like         1        0
# 2        1       2     like         1        1
# 3        1       3    heart         1        1
# 4        1       4     like         1        1
# 5        1       5    heart         1        1
# 6        1       6     like         1        1
# 7        2       1     like         2        2
# 8        2       6     like         2        2
# 9        1       2     like         2        3
# 10       1       3     like         2        3
# 11       1       4     like         2        3
# 12       1       5     like         2        3
# 13       1       6     like         2        3
# 14       2       1    laugh         1        0
# 15       2       6    laugh         1        1
# 16       1       2    laugh         1        0
# 17       1       3    laugh         1        3
# 18       1       4    laugh         1        4

# %%
pd.read_csv('facebook_posts.csv')
# Out:
#    post_id  poster                                   post_text  \
# 0        0       2  The Lakers game from last night was great.
# 1        1       1                  Lebron James is top class.
# 2        2       2                        Asparagus tastes OK.
# 3        3       1               Spaghetti is an Italian food.
# 4        4       3             User 3 is not sharing interests
# 5        5       3             User 3 posts SPAM content a lot
#
#                    post_keywords      post_date
# 0        [basketball,lakers,nba]  1/1/2019 0:00
# 1  [basketball,lebron_james,nba]  1/2/2019 0:00
# 2               [asparagus,food]  1/1/2019 0:00
# 3               [spaghetti,food]  1/2/2019 0:00
# 4                       [#spam#]  1/1/2019 0:00
# 5                       [#spam#]  1/2/2019 0:00

# %% [markdown]
# Find all posts which were reacted to with a heart. For such posts output all columns from facebook_posts table.

# %%
reactions = pd.read_csv('facebook_reactions.csv')
posts = pd.read_csv('facebook_posts.csv')

# %%
reactions[reactions['reaction']=='heart'].drop('friend',axis=1)
# Out:
#    poster reaction  date_day  post_id
# 3       1    heart         1        1
# 5       1    heart         1        1

# %%
reactions[reactions['reaction']=='heart']

# %%
pd.merge(reactions[reactions['reaction']=='heart'],posts)
# Out:
#    poster  friend reaction  date_day  post_id                   post_text  \
# 0       1       3    heart         1        1  Lebron James is top class.
# 1       1       5    heart         1        1  Lebron James is top class.
#
#                    post_keywords      post_date
# 0  [basketball,lebron_james,nba]  1/2/2019 0:00
# 1  [basketball,lebron_james,nba]  1/2/2019 0:00
