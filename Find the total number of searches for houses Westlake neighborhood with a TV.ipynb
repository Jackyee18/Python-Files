# %%
import pandas as pd

# %%
pd.read_csv('airbnb_search_details.csv')
# Out:
#            id   price property_type        room_type  \
# 0    12513361  555.68     Apartment  Entire home/apt
# 1     7196412  366.36         Cabin     Private room
# 2    16333776  482.83         House     Private room
# 3     1786412  448.86     Apartment     Private room
# 4    14575777  506.89         Villa     Private room
# ..        ...     ...           ...              ...
# 155  20257960  478.75         House     Private room
# 156   4559312  510.59     Apartment  Entire home/apt
# 157   2165604  368.89     Apartment     Private room
# 158  18385413  409.43     Apartment  Entire home/apt
# 159   9470528  477.91     Apartment  Entire home/apt
#
#                                              amenities  accommodates  \
# 0    {TV,"Wireless Internet","Air conditioning","Sm...             2
# 1    {"Wireless Internet",Kitchen,Washer,Dryer,"Smo...             2
# 2    {TV,"Cable TV",Internet,"Wireless Internet",Ki...             2
# ...

# %% [markdown]
# Find the total number of searches for houses in Westlake neighborhood with a TV among the amenities.

# %%
df = pd.read_csv('airbnb_search_details.csv')

# %%
# check all columns
df.columns
# Out:
# Index(['id', 'price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %%
# check the values of 'neighbourhood' column (if there is 'Westlake')
df.neighbourhood.unique()
# Out:
# array(['East Harlem', 'Valley Glen', 'Richmond District', 'Williamsburg',
#        nan, 'Topanga', 'Hollywood Hills', 'Long Beach',
#        'Rancho Palos Verdes', 'Malibu', 'Harbor Gateway', 'Crown Heights',
#        'Temple City', 'Bedford-Stuyvesant', 'Hollywood', 'Richmond Hill',
#        'Astoria', 'Westchester/Playa Del Rey', 'Mid-Wilshire',
#        'Mar Vista', 'Hunts Point', 'Carroll Gardens', 'Studio City',
#        'Flushing', 'Logan Circle', 'Dorchester', 'The Rockaways',
#        'Windsor Terrace', 'Bernal Heights', 'Echo Park', 'Russian Hill',
#        'Westwood', 'Santa Monica', 'South Boston', 'Marina Del Rey',
#        'Hermosa Beach', 'East New York', 'Manhattan Beach', 'Westlake',
#        'Lakeview', 'Harlem', 'Westside', 'Hawthorne', 'Gardena',
#        'Alphabet City', 'Pacific Palisades', 'Loop', 'West Hollywood',
#        'Lincoln Park', 'East Village', 'Hayes Valley', 'Park Slope',
#        "Hell's Kitchen", 'Mount Washington', 'Mission District',
# ...

# %%
# condition 1: Westlake neighborhood
df[df.neighbourhood == 'Westlake']
# Out:
#            id   price property_type        room_type  \
# 59    6391342  417.44         House     Private room
# 60   11606802  455.39         House  Entire home/apt
# 61   12289125  486.75         House  Entire home/apt
# 63     392794  270.81         House      Shared room
# 127   6692191  423.41         House     Private room
# 143  14320263  321.89         House      Shared room
#
#                                              amenities  accommodates  \
# 59   {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# 60   {TV,"Cable TV",Internet,"Wireless Internet","A...             5
# 61   {TV,Internet,"Wireless Internet","Air conditio...             6
# 63   {TV,"Cable TV",Internet,"Wireless Internet","A...             4
# 127  {TV,Internet,"Wireless Internet","Air conditio...             1
# 143  {TV,"Wireless Internet","Air conditioning",Kit...             1
#
#      bathrooms  bed_type cancellation_policy  cleaning_fee city  \
# ...

# %%
df.property_type.unique()
# Out:
# array(['Apartment', 'Cabin', 'House', 'Villa', 'Other', 'Condominium',
#        'Townhouse', 'Loft', 'Bungalow'], dtype=object)

# %%
# condition 2: searches for houses
df[df.property_type=='House']
# Out:
#            id   price property_type        room_type  \
# 2    16333776  482.83         House     Private room
# 17    4471474  313.55         House      Shared room
# 18   13207484  368.89         House      Shared room
# 19    7837072  336.73         House     Private room
# 20    7823396  417.44         House     Private room
# 21    7966742  423.41         House     Private room
# 22     257568  389.18         House     Private room
# 24   13667633  541.61         House  Entire home/apt
# 25     590903  662.01         House  Entire home/apt
# 26   19161964  391.20         House     Private room
# 27   19475815  470.05         House     Private room
# 28    1407841  412.71         House     Private room
# 29    1535628  407.75         House     Private room
# 30    6888244  501.06         House     Private room
# 31    8889145  539.36         House  Entire home/apt
# 32   15073872  474.49         House     Private room
# 33   10174146  695.65         House  Entire home/apt
# ...

# %% [markdown]
# ### Pandas: How to Check if Column Contains String

# %%
# Method 1: Check if Exact String Exists in Column
df.amenities.eq('TV').any()
# Out:
# False

# %%
# Method 2: Check if Partial String Exists in Column
df.amenities.str.contains('TV').any()
# Out:
# True

# %%
# Method 3: Count Occurrences of Partial String in Column
df.amenities.str.contains('TV').sum()
# Out:
# 117

# %% [markdown]
# /t

# %%
# condition 3: amentities include TV
df.amenities.str.contains('TV')
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 155    False
# 156    False
# 157    False
# 158     True
# 159     True
# Name: amenities, Length: 160, dtype: bool

# %%
# combine 3 conditions:
(df.amenities.str.contains('TV'))&(df.property_type=='House')&(df.neighbourhood == 'Westlake')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 155    False
# 156    False
# 157    False
# 158    False
# 159    False
# Length: 160, dtype: bool

# %%
# Final solution:
df[(df.amenities.str.contains('TV'))&(df.property_type=='House')&(df.neighbourhood == 'Westlake')]
# Out:
#            id   price property_type        room_type  \
# 59    6391342  417.44         House     Private room
# 60   11606802  455.39         House  Entire home/apt
# 61   12289125  486.75         House  Entire home/apt
# 63     392794  270.81         House      Shared room
# 127   6692191  423.41         House     Private room
# 143  14320263  321.89         House      Shared room
#
#                                              amenities  accommodates  \
# 59   {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# 60   {TV,"Cable TV",Internet,"Wireless Internet","A...             5
# 61   {TV,Internet,"Wireless Internet","Air conditio...             6
# 63   {TV,"Cable TV",Internet,"Wireless Internet","A...             4
# 127  {TV,Internet,"Wireless Internet","Air conditio...             1
# 143  {TV,"Wireless Internet","Air conditioning",Kit...             1
#
#      bathrooms  bed_type cancellation_policy  cleaning_fee city  \
# ...
